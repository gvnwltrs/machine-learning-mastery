# %% [markdown]
# # Normal Distributions

# %%
from numpy.random import normal 

mu = 50
sigma = 5 
n = 10 

sample = normal(mu, sigma, n)
print(sample)
# Out:
# [53.59756635 55.67653192 55.78476947 50.60969707 46.35351747 51.34999724
#  44.23532335 46.78364592 52.65057707 50.80829741]

# %%
from scipy.stats import norm
from matplotlib import pyplot

mu = 50
sigma = 5
dist = norm(mu, sigma)

values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]
pyplot.plot(values, probabilities)
pyplot.show()

cprobs = [dist.cdf(value) for value in values]
pyplot.plot(values, cprobs)
pyplot.show()

# %%
from scipy.stats import norm

mu = 50
sigma = 5 

dist = norm(mu, sigma)
low_end = dist.ppf(0.025)
high_end = dist.ppf(0.975)
print('Middle 95% between {0} and {1}'.format(low_end, high_end))
# Out:
# Middle 95% between 40.20018007729973 and 59.799819922700266
